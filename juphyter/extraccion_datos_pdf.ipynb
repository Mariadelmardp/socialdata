# %%
import os
import time
import pandas as pd
import pdfplumber
from openai import OpenAI
from typing import List, Dict, Any
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor

# %%
# Configuración inicial
PDF_PATH = r"C:\Users\maria\Desktop\data\we are social\Digital_2025_Spain_v02.pdf"  # Ruta al archivo PDF
OUTPUT_EXCEL = "datos_estructurados.xlsx"  # Archivo Excel de salida
OPENAI_API_KEY = "tu_api_key_aqui"  # Tu API key de OpenAI
MAX_WORKERS = 4  # Número de trabajadores concurrentes (ajustar según necesidad)
# Inicializar cliente de OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
def extract_text_from_page(pdf_path: str, page_num: int) -> str:
    """Extrae el texto de una página específica del PDF"""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            if page_num < len(pdf.pages):
                page = pdf.pages[page_num]
                return page.extract_text() or ""
            else:
                return ""
    except Exception as e:
        print(f"Error al extraer texto de la página {page_num}: {e}")
        return ""

# %%
def extract_text_from_page(pdf_path: str, page_num: int) -> str:
    """Extrae el texto de una página específica del PDF"""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            if page_num < len(pdf.pages):
                page = pdf.pages[page_num]
                return page.extract_text() or ""
            else:
                return ""
    except Exception as e:
        print(f"Error al extraer texto de la página {page_num}: {e}")
        return ""

# %%
def translate_and_extract_data(text: str, page_num: int) -> Dict[str, Any]:
    """Traduce el texto al español y extrae datos estructurados usando IA"""
    if not text.strip():
        return {"page_number": page_num, "data": {}, "error": "Página vacía o sin texto"}
    
    try:
        # Prompt para la IA que realiza la traducción y extracción
        prompt = f"""
        Esta es la página {page_num} de un informe. Por favor:
        
        1. Traduce el siguiente texto del inglés al español:
        
        {text}
        
        2. Después de traducir, identifica y extrae todos los datos numéricos, estadísticas, 
        porcentajes y métricas relevantes que aparezcan en el texto. Devuelve estos datos 
        en formato JSON, donde cada clave sea el nombre del dato/métrica (en español) y 
        el valor sea el dato numérico con su unidad.
        
        3. Si hay tablas o gráficos descritos, extrae también esa información estructurada.
        
        Por favor, proporciona dos secciones:
        1. "traduccion": El texto completo traducido
        2. "datos": Un objeto JSON con los datos estructurados extraídos
        """
        
        # Llamada a la API de OpenAI
        response = client.chat.completions.create(
            model="gpt-4o",  # Puedes usar gpt-3.5-turbo para reducir costos
            messages=[
                {"role": "system", "content": "Eres un asistente experto en traducción y extracción de datos de informes estadísticos."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.1,  # Temperatura baja para respuestas más consistentes
            response_format={"type": "json_object"}
        )
        
        # Procesar la respuesta y extraer datos
        result = response.choices[0].message.content
        
        # Convertir la respuesta a formato JSON (la respuesta ya debe venir en formato JSON)
        import json
        parsed_result = json.loads(result)
        
        return {
            "page_number": page_num,
            "translation": parsed_result.get("traduccion", ""),
            "data": parsed_result.get("datos", {}),
            "error": None
        }
        
    except Exception as e:
        print(f"Error en la página {page_num}: {e}")
        return {
            "page_number": page_num,
            "translation": "",
            "data": {},
            "error": str(e)}

# %%
def process_pdf(pdf_path: str, start_page: int = 0, end_page: int = None) -> List[Dict[str, Any]]:
    """Procesa el PDF completo o un rango de páginas especificado"""
    results = []
    
    # Determinar el número total de páginas
    with pdfplumber.open(pdf_path) as pdf:
        total_pages = len(pdf.pages)
    
    if end_page is None or end_page > total_pages:
        end_page = total_pages
    
    print(f"Procesando PDF: {pdf_path}")
    print(f"Total de páginas a procesar: {end_page - start_page}")
    
    # Lista para almacenar las tareas
    tasks = []
    
    # Crear tareas para el procesamiento concurrente
    for page_num in range(start_page, end_page):
        # Extraer texto de la página
        text = extract_text_from_page(pdf_path, page_num)
        tasks.append((text, page_num))
    
    # Procesar páginas con múltiples hilos
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        # Mapear cada tarea al método translate_and_extract_data
        future_to_page = {executor.submit(translate_and_extract_data, text, page_num): page_num 
                          for text, page_num in tasks}
        
        # Recopilar resultados a medida que se completan
        for i, future in enumerate(concurrent.futures.as_completed(future_to_page)):
            page_num = future_to_page[future]
            try:
                result = future.result()
                results.append(result)
                
                # Imprimir progreso
                print(f"Completado {i+1}/{len(tasks)}: Página {page_num+1}")
                
                # Pausa breve para no sobrecargar la API
                time.sleep(0.5)
                
            except Exception as e:
                print(f"Error procesando página {page_num+1}: {e}")
                results.append({
                    "page_number": page_num,
                    "translation": "",
                    "data": {},
                    "error": str(e)
                })
    
    # Ordenar resultados por número de página
    results.sort(key=lambda x: x["page_number"])
    return results

# %%
def save_to_excel(results: List[Dict[str, Any]], output_file: str):
    """Guarda los resultados en un archivo Excel"""
    # Crear un DataFrame para la hoja de datos estructurados
    all_data = []
    
    for result in results:
        page_num = result["page_number"] + 1  # +1 para que empiece en 1 en lugar de 0
        data = result["data"]
        
        # Agregar cada dato con su página de origen
        for key, value in data.items():
            all_data.append({
                "Página": page_num,
                "Métrica": key,
                "Valor": value
            })
    
    # Crear DataFrame
    df_data = pd.DataFrame(all_data)
    
    # Crear un Excel con múltiples hojas
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        # Hoja 1: Datos estructurados
        if not df_data.empty:
            df_data.to_excel(writer, sheet_name='Datos Estructurados', index=False)
        
        # Hoja 2: Traducciones completas
        translations = [{
            "Página": result["page_number"] + 1,
            "Texto Traducido": result["translation"]
        } for result in results]
        
        df_translations = pd.DataFrame(translations)
        df_translations.to_excel(writer, sheet_name='Traducciones', index=False)
        
        # Hoja 3: Registro de errores
        errors = [{
            "Página": result["page_number"] + 1,
            "Error": result["error"]
        } for result in results if result["error"]]
        
        if errors:
            df_errors = pd.DataFrame(errors)
            df_errors.to_excel(writer, sheet_name='Errores', index=False)
    
    print(f"Resultados guardados en: {output_file}")

# %%
def main():
    """Función principal"""
    start_time = time.time()
    
    # Procesar el PDF completo
    results = process_pdf(PDF_PATH)
    
    # Guardar resultados en Excel
    save_to_excel(results, OUTPUT_EXCEL)
    
    # Calcular tiempo total de procesamiento
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Proceso completado en {elapsed_time / 60:.2f} minutos")

if __name__ == "__main__":
    main()
# Out:
# Procesando PDF: C:\Users\maria\Desktop\data\we are social\Digital_2025_Spain_v02.pdf
# Total de páginas a procesar: 167
# Completado 1/167: Página 2
# Error en la página 0: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 2/167: Página 1
# Error en la página 4: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 2: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 3: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 5: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}Error en la página 7: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# Error en la página 6: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 8: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 10: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 9: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 12: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 11: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 3/167: Página 5
# Error en la página 14: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 13: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 15: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 16: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 17: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 18: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 19: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 20: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 4/167: Página 3
# Error en la página 21: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 22: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 24: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 23: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 25: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 26: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 27: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 28: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 29: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 30: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 5/167: Página 4
# Error en la página 31: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 33: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 32: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 34: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 35: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 36: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 37: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 38: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 39: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 40: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 41: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 6/167: Página 8
# Error en la página 42: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 43: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 44: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 45: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 46: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 47: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 48: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 49: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 50: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 51: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 7/167: Página 6
# Error en la página 52: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 53: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 54: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 55: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 56: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 57: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 58: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 59: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 60: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 61: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 62: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 8/167: Página 7
# Error en la página 63: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 64: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 65: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 66: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 68: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 67: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 69: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 70: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 71: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 72: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 9/167: Página 9
# Error en la página 74: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 73: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 75: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 76: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 77: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 78: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 79: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 80: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 81: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 82: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 10/167: Página 11
# Error en la página 84: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 83: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 85: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 86: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 87: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 88: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 89: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 11/167: Página 10
# Error en la página 91: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 93: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 92: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 90: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 94: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 96: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 95: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 97: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 12/167: Página 13
# Error en la página 101: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 100: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 98: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 99: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 103: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 105: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 13/167: Página 12
# Error en la página 102: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 104: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 108: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 109: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 106: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 107: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 112: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 111: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 14/167: Página 15
# Error en la página 110: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 113: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 115: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 116: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 117: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 114: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 118: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 119: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 120: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 15/167: Página 14
# Error en la página 121: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 122: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 124: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 123: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 125: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 16/167: Página 16
# Error en la página 127: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 128: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 129: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 126: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 131: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 132: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 130: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 133: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 17/167: Página 17
# Error en la página 135: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 136: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 134: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 137: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 140: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 138: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 139: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 141: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 18/167: Página 18
# Error en la página 142: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 144: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 145: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 143: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 146: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 149: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 148: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 147: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 150: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 19/167: Página 19
# Error en la página 151: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 153: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 152: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 154: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 156: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 157: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 158: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 159: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 160: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 163: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 162: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 20/167: Página 20
# Error en la página 164: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 165: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Error en la página 166: Error code: 401 - {'error': {'message': 'Incorrect API key provided: tu_api_k***aqui. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# Completado 21/167: Página 21
# Completado 22/167: Página 22
# Completado 23/167: Página 23
# Completado 24/167: Página 25
# Completado 25/167: Página 24
# Completado 26/167: Página 26
# Completado 27/167: Página 27
# Completado 28/167: Página 28
# Completado 29/167: Página 29
# Completado 30/167: Página 30
# Completado 31/167: Página 31
# Completado 32/167: Página 32
# Completado 33/167: Página 34
# Completado 34/167: Página 33
# Completado 35/167: Página 35
# Completado 36/167: Página 36
# Completado 37/167: Página 37
# Completado 38/167: Página 38
# Completado 39/167: Página 39
# Completado 40/167: Página 40
# Completado 41/167: Página 41
# Completado 42/167: Página 42
# Completado 43/167: Página 43
# Completado 44/167: Página 44
# Completado 45/167: Página 45
# Completado 46/167: Página 46
# Completado 47/167: Página 47
# Completado 48/167: Página 48
# Completado 49/167: Página 49
# Completado 50/167: Página 50
# Completado 51/167: Página 51
# Completado 52/167: Página 52
# Completado 53/167: Página 53
# Completado 54/167: Página 54
# Completado 55/167: Página 55
# Completado 56/167: Página 56
# Completado 57/167: Página 57
# Completado 58/167: Página 58
# Completado 59/167: Página 59
# Completado 60/167: Página 60
# Completado 61/167: Página 61
# Completado 62/167: Página 62
# Completado 63/167: Página 63
# Completado 64/167: Página 64
# Completado 65/167: Página 65
# Completado 66/167: Página 66
# Completado 67/167: Página 67
# Completado 68/167: Página 69
# Completado 69/167: Página 68
# Completado 70/167: Página 70
# Completado 71/167: Página 71
# Completado 72/167: Página 72
# Completado 73/167: Página 73
# Completado 74/167: Página 75
# Completado 75/167: Página 74
# Completado 76/167: Página 76
# Completado 77/167: Página 77
# Completado 78/167: Página 78
# Completado 79/167: Página 79
# Completado 80/167: Página 80
# Completado 81/167: Página 81
# Completado 82/167: Página 82
# Completado 83/167: Página 83
# Completado 84/167: Página 85
# Completado 85/167: Página 84
# Completado 86/167: Página 86
# Completado 87/167: Página 87
# Completado 88/167: Página 88
# Completado 89/167: Página 89
# Completado 90/167: Página 90
# Completado 91/167: Página 92
# Completado 92/167: Página 94
# Completado 93/167: Página 93
# Completado 94/167: Página 91
# Completado 95/167: Página 95
# Completado 96/167: Página 97
# Completado 97/167: Página 96
# Completado 98/167: Página 98
# Completado 99/167: Página 102
# Completado 100/167: Página 101
# Completado 101/167: Página 99
# Completado 102/167: Página 100
# Completado 103/167: Página 104
# Completado 104/167: Página 106
# Completado 105/167: Página 103
# Completado 106/167: Página 105
# Completado 107/167: Página 109
# Completado 108/167: Página 110
# Completado 109/167: Página 107
# Completado 110/167: Página 108
# Completado 111/167: Página 113
# Completado 112/167: Página 112
# Completado 113/167: Página 111
# Completado 114/167: Página 114
# Completado 115/167: Página 116
# Completado 116/167: Página 117
# Completado 117/167: Página 118
# Completado 118/167: Página 115
# Completado 119/167: Página 119
# Completado 120/167: Página 120
# Completado 121/167: Página 121
# Completado 122/167: Página 122
# Completado 123/167: Página 123
# Completado 124/167: Página 125
# Completado 125/167: Página 124
# Completado 126/167: Página 126
# Completado 127/167: Página 128
# Completado 128/167: Página 129
# Completado 129/167: Página 130
# Completado 130/167: Página 127
# Completado 131/167: Página 132
# Completado 132/167: Página 133
# Completado 133/167: Página 131
# Completado 134/167: Página 134
# Completado 135/167: Página 136
# Completado 136/167: Página 137
# Completado 137/167: Página 135
# Completado 138/167: Página 138
# Completado 139/167: Página 141
# Completado 140/167: Página 139
# Completado 141/167: Página 140
# Completado 142/167: Página 142
# Completado 143/167: Página 143
# Completado 144/167: Página 145
# Completado 145/167: Página 146
# Completado 146/167: Página 144
# Completado 147/167: Página 147
# Completado 148/167: Página 150
# Completado 149/167: Página 149
# Completado 150/167: Página 148
# Completado 151/167: Página 151
# Completado 152/167: Página 152
# Completado 153/167: Página 156
# Completado 154/167: Página 154
# Completado 155/167: Página 153
# Completado 156/167: Página 155
# Completado 157/167: Página 157
# Completado 158/167: Página 158
# Completado 159/167: Página 162
# Completado 160/167: Página 159
# Completado 161/167: Página 160
# Completado 162/167: Página 161
# Completado 163/167: Página 164
# Completado 164/167: Página 163
# Completado 165/167: Página 165
# Completado 166/167: Página 166
# Completado 167/167: Página 167
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 30, in save_to_excel(results, output_file)
#      27 # Hoja 2: Traducciones completas
#      28 translations = [{
#      29     "Página": result["page_number"] + 1,
# ---> 30     "Texto Traducido": result["translation"]
#      31 } for result in results]
#      33 df_translations = pd.DataFrame(translations)
#
# KeyError: 'translation'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 17
#      14     print(f"Proceso completado en {elapsed_time / 60:.2f} minutos")
#      16 if __name__ == "__main__":
# ---> 17     main()
#
# Cell In[26], line 9, in main()
#       6 results = process_pdf(PDF_PATH)
#       8 # Guardar resultados en Excel
# ----> 9 save_to_excel(results, OUTPUT_EXCEL)
#      11 # Calcular tiempo total de procesamiento
#      12 end_time = time.time()
#
# Cell In[25], line 22, in save_to_excel(results, output_file)
#      19 df_data = pd.DataFrame(all_data)
#      21 # Crear un Excel con múltiples hojas
# ---> 22 with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
#      23     # Hoja 1: Datos estructurados
#      24     if not df_data.empty:
#      25         df_data.to_excel(writer, sheet_name='Datos Estructurados', index=False)
#
# File c:\Users\maria\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1353, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1347 def __exit__(
#    1348     self,
#    1349     exc_type: type[BaseException] | None,
#    1350     exc_value: BaseException | None,
#    1351     traceback: TracebackType | None,
#    1352 ) -> None:
# -> 1353     self.close()
#
# File c:\Users\maria\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\maria\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.utcnow()
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\writer\excel.py:89, in ExcelWriter.write_data(self)
#      87 writer = WorkbookWriter(self.workbook)
#      88 archive.writestr(ARC_ROOT_RELS, writer.write_root_rels())
# ---> 89 archive.writestr(ARC_WORKBOOK, writer.write())
#      90 archive.writestr(ARC_WORKBOOK_RELS, writer.write_rels())
#      92 self._merge_vba()
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\workbook\_writer.py:150, in WorkbookWriter.write(self)
#     148 self.write_names()
#     149 self.write_pivots()
# --> 150 self.write_views()
#     151 self.write_refs()
#     153 return tostring(self.package.to_tree())
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\workbook\_writer.py:137, in WorkbookWriter.write_views(self)
#     136 def write_views(self):
# --> 137     active = get_active_sheet(self.wb)
#     138     if self.wb.views:
#     139         self.wb.views[0].activeTab = active
#
# File c:\Users\maria\anaconda3\Lib\site-packages\openpyxl\workbook\_writer.py:35, in get_active_sheet(wb)
#      33 visible_sheets = [idx for idx, sheet in enumerate(wb._sheets) if sheet.sheet_state == "visible"]
#      34 if not visible_sheets:
# ---> 35     raise IndexError("At least one sheet must be visible")
#      37 idx = wb._active_sheet_index
#      38 sheet = wb.active
#
# IndexError: At least one sheet must be visible
